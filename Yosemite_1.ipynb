# %%
from osgeo import gdal
import matplotlib.pyplot as plt


dataset = gdal.Open(r'/content/drive/MyDrive/Yosemite/Elevation2.tif')

# %%
band1 = dataset.GetRasterBand(1)

# %%
b1 = dataset.ReadAsArray()

# %%
f = plt.figure()
plt.imshow(b1)
plt.savefig('Tiff.png')
plt.show()
